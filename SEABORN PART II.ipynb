# %% [markdown]
# ![](thumbnail.jpg)

# %% [markdown]
# ---

# %% [markdown]
# **CODE SOURCE + MEDIAS SOCIAUX**
#
# - [Vidéo associée à ce notebook]( https://youtu.be/R_mmdGrWRZI )
#
# - [Playlist complete](https://urlz.fr/kvpG)
#
# - [Mon profile linkedin](https://www.linkedin.com/in/ousman-hamit-hassani/)
#
# - [Groupe facebook](https://www.facebook.com/groups/openclass4all/)
#
# - [Instagram](https://www.instagram.com/openclass4all/)
#
# - [Github](https://www.github.com/ousmanhamit/)
#
#
# Merci d’ajouter une étoile à mon profile github si vous pensez que le travail que je fais est utile.

# %% [markdown]
# ---

# %%
import seaborn as sns
from matplotlib import pyplot as plt
sns.set_style("darkgrid")

# %% [markdown]
# ---

# %%
df = sns.load_dataset("titanic")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.select_dtypes(exclude = ['number']).head()
# Out:
#       sex embarked  class    who  adult_male deck  embark_town alive  alone
# 0    male        S  Third    man        True  NaN  Southampton    no  False
# 1  female        C  First  woman       False    C    Cherbourg   yes  False
# 2  female        S  Third  woman       False  NaN  Southampton   yes   True
# 3  female        S  First  woman       False    C  Southampton   yes  False
# 4    male        S  Third    man        True  NaN  Southampton    no   True

# %%
df['class'].value_counts()
# Out:
# Third     491
# First     216
# Second    184
# Name: class, dtype: int64

# %%
for colname in enumerate(df.select_dtypes(exclude = ['number'])):
    print(colname)
# Out:
# (0, 'sex')
# (1, 'embarked')
# (2, 'class')
# (3, 'who')
# (4, 'adult_male')
# (5, 'deck')
# (6, 'embark_town')
# (7, 'alive')
# (8, 'alone')

# %%
plt.figure(figsize=(16, 10))
for colname in enumerate(df.select_dtypes(exclude = ['number'])):
    plt.subplot(3,3, colname[0] + 1)
    sns.countplot(x = colname[1], hue = 'class', data = df)
plt.show()

# %%
plt.figure(figsize=(16, 10))
for colname in enumerate(df.select_dtypes(exclude = ['number'])):
    plt.subplot(3,3, colname[0] + 1)
    sns.countplot(x = colname[1], hue = 'sex', data = df)
plt.show()

# %%
df.select_dtypes(include = ['number']).head()
# Out:
#    survived  pclass   age  sibsp  parch     fare
# 0         0       3  22.0      1      0   7.2500
# 1         1       1  38.0      1      0  71.2833
# 2         1       3  26.0      0      0   7.9250
# 3         1       1  35.0      1      0  53.1000
# 4         0       3  35.0      0      0   8.0500

# %%
plt.figure(figsize=(16, 10))
for colname in enumerate(df.select_dtypes(include = ['number'])):
    plt.subplot(2,3, colname[0] + 1)
    sns.histplot(x = colname[1], data = df)
plt.show()
